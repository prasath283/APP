# %%
import multiprocessing
def worker(num):
 print('Worker:', num)
 for i in range(num):
   print(i)
 return
jobs = []
for i in range(1,5):
 p = multiprocessing.Process(target=worker, args=(i+10,))
 jobs.append(p)
 p.start()
# Out:
# Worker: 12
# 0
# Worker: 13
# Worker: 11
# Worker: 14
# 0
# 0
# 0
# 1
# 1
# 1
# 2
# 2
# 1
# 2
# 3
# 3
# 4
# 3
# 4
# 2
# 4
# 5
# 3
# 6
# 7
# 8
# 5
# 6
# 4
# 5
# 5
# 6
# 7
# 6
# 9
# 8
# 7
# 10
# 8
# 7
# 9
# 8
# 9
# 11
# 10
# 12
# 10
# 9
# 11
# 10
# 11
# 12
# 13
